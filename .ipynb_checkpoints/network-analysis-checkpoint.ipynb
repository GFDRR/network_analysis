# %%
import osmnx as ox

# %%
import geopandas as gpd
import pandas as pd
import pylab as plt
# %pylab inline
import GOSTnet as gn
# Out:
# Populating the interactive namespace from numpy and matplotlib
# peartree version: 0.6.1
# networkx version: 2.3
# matplotlib version: 3.0.3
# osmnx version: 0.10
# /Users/nicholasjones/anaconda3/envs/GPD_OSM/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
G = ox.graph_from_place('Maidstone, Kent, UK')

# %%
print(1)
# Out:
# 1

# %%
G

# %%
f,ax = plt.subplots()
gdf1.plot(ax=ax)
gdf2.plot(ax=ax)
pois.plot(color = 'r', ax = ax,zorder=3)

# %%
gdf1, gdf2 = ox.graph_to_gdfs(G)

# %%
pois = ox.pois_from_place('Maidstone, Kent, UK', ['pub'])

# %%
pois.plot()

# %%
# !ls
# Out:
# CDMX2.ipynb              __pycache__              data
# HeroinOverdosesJumpy.mp4 animate                  grid.dbf
# MX_1.ipynb               animate_CDMX.ipynb       grid.shp
# Untitled.ipynb           basic_animation.mp4      grid.shx
# Untitled1.ipynb          celluloid_minimal.htm    location_tools.py
# Untitled2.ipynb          celluloid_minimal_frames make_animation_1.ipynb
# Untitled3.ipynb          cuebiq2.ipynb            make_fishnet.py
